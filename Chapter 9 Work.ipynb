# %% [markdown]
# #Chapter 9 Programming Exercise Question 2

# %%
import random

# U.S. states and their capitals
us_states = {
    'Alabama': 'Montgomery',
    'Alaska': 'Juneau',
    'Arizona': 'Phoenix',
    'Arkansas': 'Little Rock',
    'California': 'Sacramento',
    'Colorado': 'Denver',
    'Connecticut': 'Hartford',
    'Delaware': 'Dover',
    'Florida': 'Tallahassee',
    'Georgia': 'Atlanta',
    'Hawaii': 'Honolulu',
    'Idaho': 'Boise',
    'Illinois': 'Springfield',
    'Indiana': 'Indianapolis',
    'Iowa': 'Des Moines',
    'Kansas': 'Topeka',
    'Kentucky': 'Frankfort',
    'Louisiana': 'Baton Rouge',
    'Maine': 'Augusta',
    'Maryland': 'Annapolis',
    'Massachusetts': 'Boston',
    'Michigan': 'Lansing',
    'Minnesota': 'St. Paul',
    'Mississippi': 'Jackson',
    'Missouri': 'Jefferson City',
    'Montana': 'Helena',
    'Nebraska': 'Lincoln',
    'Nevada': 'Carson City',
    'New Hampshire': 'Concord',
    'New Jersey': 'Trenton',
    'New Mexico': 'Santa Fe',
    'New York': 'Albany',
    'North Carolina': 'Raleigh',
    'North Dakota': 'Bismarck',
    'Ohio': 'Columbus',
    'Oklahoma': 'Oklahoma City',
    'Oregon': 'Salem',
    'Pennsylvania': 'Harrisburg',
    'Rhode Island': 'Providence',
    'South Carolina': 'Columbia',
    'South Dakota': 'Pierre',
    'Tennessee': 'Nashville',
    'Texas': 'Austin',
    'Utah': 'Salt Lake City',
    'Vermont': 'Montpelier',
    'Virginia': 'Richmond',
    'Washington': 'Olympia',
    'West Virginia': 'Charleston',
    'Wisconsin': 'Madison',
    'Wyoming': 'Cheyenne'
}

def main():
    print("Welcome to the U.S. States Capitals Quiz!")
    quiz()

def quiz():
    correct_answers = 0
    incorrect_answers = 0

    states = list(us_states.keys())

    while states:
        state = random.choice(states)
        correct_capital = us_states[state]

        print(f"What is the capital of {state}? (Type 'exit' to quit)")
        user_input = input("Your answer: ")

        if user_input.lower() == 'exit':
            break

        if user_input == correct_capital:
            print("Correct!\n")
            correct_answers += 1
        else:
            print(f"Incorrect. The correct answer is {correct_capital}.\n")
            incorrect_answers += 1

        states.remove(state)

    print(f"Quiz ended. You got {correct_answers} correct and {incorrect_answers} incorrect answers.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the U.S. States Capitals Quiz!
# What is the capital of Massachusetts? (Type 'exit' to quit)
# Your answer: Boston
# Correct!
#
# What is the capital of Maine? (Type 'exit' to quit)
# Your answer: Augusta
# Correct!
#
# What is the capital of South Dakota? (Type 'exit' to quit)
# Your answer: Pierre
# Correct!
#
# What is the capital of Wyoming? (Type 'exit' to quit)
# Your answer: Cheyenne
# Correct!
#
# What is the capital of Kansas? (Type 'exit' to quit)
# Your answer: Topeka
# Correct!
#
# What is the capital of Idaho? (Type 'exit' to quit)
# Your answer: Lansin
# Incorrect. The correct answer is Boise.
#
# What is the capital of Florida? (Type 'exit' to quit)
# Your answer: Tallahasse
# Incorrect. The correct answer is Tallahassee.
#
# What is the capital of Michigan? (Type 'exit' to quit)
# Your answer: Lansing
# Correct!
#
# What is the capital of Utah? (Type 'exit' to quit)
# Your answer: Boise
# Incorrect. The correct answer is Salt Lake City.
#
# ...
